# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('House Price India.csv')
df
# Out:
#                id   Date  number of bedrooms  number of bathrooms  \
# 0      6762810635  42491                   4                 2.50
# 1      6762810998  42491                   5                 2.75
# 2      6762812605  42491                   4                 2.50
# 3      6762812919  42491                   3                 2.00
# 4      6762813105  42491                   3                 2.50
# ...           ...    ...                 ...                  ...
# 14614  6762830250  42734                   2                 1.50
# 14615  6762830339  42734                   3                 2.00
# 14616  6762830618  42734                   2                 1.00
# 14617  6762830709  42734                   4                 1.00
# 14618  6762831463  42734                   3                 1.00
#
#        living area  lot area  number of floors  waterfront present  \
# 0             2920      4000               1.5                   0
# ...

# %%
df.shape
# Out:
# (14619, 23)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14619 entries, 0 to 14618
# Data columns (total 23 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   id                                     14619 non-null  int64
#  1   Date                                   14619 non-null  int64
#  2   number of bedrooms                     14619 non-null  int64
#  3   number of bathrooms                    14619 non-null  float64
#  4   living area                            14619 non-null  int64
#  5   lot area                               14619 non-null  int64
#  6   number of floors                       14619 non-null  float64
#  7   waterfront present                     14619 non-null  int64
#  8   number of views                        14619 non-null  int64
#  9   condition of the house                 14619 non-null  int64
# ...

# %%
df.mean()
# Out:
# id                                       6.762821e+09
# Date                                     4.260455e+04
# number of bedrooms                       3.379233e+00
# number of bathrooms                      2.129557e+00
# living area                              2.098157e+03
# lot area                                 1.509369e+04
# number of floors                         1.502326e+00
# waterfront present                       7.661263e-03
# number of views                          2.328477e-01
# condition of the house                   3.430399e+00
# grade of the house                       7.682263e+00
# Area of the house(excluding basement)    1.801677e+03
# Area of the basement                     2.964802e+02
# Built Year                               1.970930e+03
# Renovation Year                          9.093023e+01
# Postal Code                              1.220331e+05
# Lattitude                                5.279284e+01
# ...

# %%
df.median()
# Out:
# id                                       6.762821e+09
# Date                                     4.260000e+04
# number of bedrooms                       3.000000e+00
# number of bathrooms                      2.250000e+00
# living area                              1.930000e+03
# lot area                                 7.620000e+03
# number of floors                         1.500000e+00
# waterfront present                       0.000000e+00
# number of views                          0.000000e+00
# condition of the house                   3.000000e+00
# grade of the house                       7.000000e+00
# Area of the house(excluding basement)    1.580000e+03
# Area of the basement                     0.000000e+00
# Built Year                               1.975000e+03
# Renovation Year                          0.000000e+00
# Postal Code                              1.220320e+05
# Lattitude                                5.280640e+01
# ...

# %%
df.std()
# Out:
# id                                         6237.161975
# Date                                         67.343747
# number of bedrooms                            0.938655
# number of bathrooms                           0.769955
# living area                                 928.218740
# lot area                                  37920.885355
# number of floors                              0.540241
# waterfront present                            0.087196
# number of views                               0.765651
# condition of the house                        0.664047
# grade of the house                            1.174917
# Area of the house(excluding basement)       833.737588
# Area of the basement                        448.566731
# Built Year                                   29.491743
# Renovation Year                             416.230218
# Postal Code                                  19.081451
# Lattitude                                     0.137525
# ...

# %%
sns.heatmap(df.corr())
# Out:
# <Axes: >

# %%
df.min()
# Out:
# id                                       6.762810e+09
# Date                                     4.249100e+04
# number of bedrooms                       1.000000e+00
# number of bathrooms                      5.000000e-01
# living area                              3.700000e+02
# lot area                                 5.200000e+02
# number of floors                         1.000000e+00
# waterfront present                       0.000000e+00
# number of views                          0.000000e+00
# condition of the house                   1.000000e+00
# grade of the house                       4.000000e+00
# Area of the house(excluding basement)    3.700000e+02
# Area of the basement                     0.000000e+00
# Built Year                               1.900000e+03
# Renovation Year                          0.000000e+00
# Postal Code                              1.220030e+05
# Lattitude                                5.238590e+01
# ...

# %%
df.max()
# Out:
# id                                       6.762832e+09
# Date                                     4.273400e+04
# number of bedrooms                       3.300000e+01
# number of bathrooms                      8.000000e+00
# living area                              1.354000e+04
# lot area                                 1.074218e+06
# number of floors                         3.500000e+00
# waterfront present                       1.000000e+00
# number of views                          4.000000e+00
# condition of the house                   5.000000e+00
# grade of the house                       1.300000e+01
# Area of the house(excluding basement)    9.410000e+03
# Area of the basement                     4.820000e+03
# Built Year                               2.015000e+03
# Renovation Year                          2.015000e+03
# Postal Code                              1.220720e+05
# Lattitude                                5.300760e+01
# ...

# %%
df.head()
# Out:
#            id   Date  number of bedrooms  number of bathrooms  living area  \
# 0  6762810635  42491                   4                 2.50         2920
# 1  6762810998  42491                   5                 2.75         2910
# 2  6762812605  42491                   4                 2.50         3310
# 3  6762812919  42491                   3                 2.00         2710
# 4  6762813105  42491                   3                 2.50         2600
#
#    lot area  number of floors  waterfront present  number of views  \
# 0      4000               1.5                   0                0
# 1      9480               1.5                   0                0
# 2     42998               2.0                   0                0
# 3      4500               1.5                   0                0
# 4      4750               1.0                   0                0
#
#    condition of the house  ...  Built Year  Renovation Year  Postal Code  \
# ...

# %%
df.tail()
# Out:
#                id   Date  number of bedrooms  number of bathrooms  \
# 14614  6762830250  42734                   2                  1.5
# 14615  6762830339  42734                   3                  2.0
# 14616  6762830618  42734                   2                  1.0
# 14617  6762830709  42734                   4                  1.0
# 14618  6762831463  42734                   3                  1.0
#
#        living area  lot area  number of floors  waterfront present  \
# 14614         1556     20000               1.0                   0
# 14615         1680      7000               1.5                   0
# 14616         1070      6120               1.0                   0
# 14617         1030      6621               1.0                   0
# 14618          900      4770               1.0                   0
#
#        number of views  condition of the house  ...  Built Year  \
# 14614                0                       4  ...        1957
# ...

# %%
df.count()
# Out:
# id                                       14619
# Date                                     14619
# number of bedrooms                       14619
# number of bathrooms                      14619
# living area                              14619
# lot area                                 14619
# number of floors                         14619
# waterfront present                       14619
# number of views                          14619
# condition of the house                   14619
# grade of the house                       14619
# Area of the house(excluding basement)    14619
# Area of the basement                     14619
# Built Year                               14619
# Renovation Year                          14619
# Postal Code                              14619
# Lattitude                                14619
# Longitude                                14619
# living_area_renov                        14619
# lot_area_renov                           14619
# ...

# %%
df.describe()
# Out:
#                  id          Date  number of bedrooms  number of bathrooms  \
# count  1.461900e+04  14619.000000        14619.000000         14619.000000
# mean   6.762821e+09  42604.546412            3.379233             2.129557
# std    6.237162e+03     67.343747            0.938655             0.769955
# min    6.762810e+09  42491.000000            1.000000             0.500000
# 25%    6.762815e+09  42546.000000            3.000000             1.750000
# 50%    6.762821e+09  42600.000000            3.000000             2.250000
# 75%    6.762826e+09  42662.000000            4.000000             2.500000
# max    6.762832e+09  42734.000000           33.000000             8.000000
#
#         living area      lot area  number of floors  waterfront present  \
# count  14619.000000  1.461900e+04      14619.000000        14619.000000
# mean    2098.156851  1.509369e+04          1.502326            0.007661
# std      928.218740  3.792089e+04          0.540241            0.087196
# ...

# %%
df.isnull().sum()
# Out:
# id                                       0
# Date                                     0
# number of bedrooms                       0
# number of bathrooms                      0
# living area                              0
# lot area                                 0
# number of floors                         0
# waterfront present                       0
# number of views                          0
# condition of the house                   0
# grade of the house                       0
# Area of the house(excluding basement)    0
# Area of the basement                     0
# Built Year                               0
# Renovation Year                          0
# Postal Code                              0
# Lattitude                                0
# Longitude                                0
# living_area_renov                        0
# lot_area_renov                           0
# Number of schools nearby                 0
# Distance from the airport                0
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
sns.boxplot(x='living area',data=df)
# Out:
# <Axes: xlabel='living area'>

# %%
df.head()
# Out:
#            id   Date  number of bedrooms  number of bathrooms  living area  \
# 0  6762810635  42491                   4                 2.50         2920
# 1  6762810998  42491                   5                 2.75         2910
# 2  6762812605  42491                   4                 2.50         3310
# 3  6762812919  42491                   3                 2.00         2710
# 4  6762813105  42491                   3                 2.50         2600
#
#    lot area  number of floors  waterfront present  number of views  \
# 0      4000               1.5                   0                0
# 1      9480               1.5                   0                0
# 2     42998               2.0                   0                0
# 3      4500               1.5                   0                0
# 4      4750               1.0                   0                0
#
#    condition of the house  ...  Built Year  Renovation Year  Postal Code  \
# ...

# %%
# Function to remove outliers based on IQR method for specified columns
def remove_outliers_iqr(df, columns):
    for col in columns:
        Q1 = df[col].quantile(0.25)
        Q3 = df[col].quantile(0.75)
        IQR = Q3 - Q1
        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR
        df = df[(df[col] >= lower_bound) & (df[col] <= upper_bound)]
    return df

# Specify the columns to remove outliers from
columns_to_check = ['number of bedrooms', 'number of bathrooms',
       'living area', 'lot area', 'number of floors', 'waterfront present',
       'number of views', 'condition of the house', 'grade of the house',
       'Area of the house(excluding basement)', 'Area of the basement',
       'Built Year', 'Renovation Year','Lattitude',
       'Longitude', 'living_area_renov', 'lot_area_renov',
       'Number of schools nearby', 'Distance from the airport']

# Remove outliers from the specified columns
df = remove_outliers_iqr(df, columns_to_check)

# Print the DataFrame before and after removing outliers
print("Original DataFrame:")
print(df)
print("\nDataFrame after removing outliers from specified columns:")
print()
# Out:
# Original DataFrame:
#                id   Date  number of bedrooms  number of bathrooms  \
# 0      6762810635  42491                   4                 2.50
# 1      6762810998  42491                   5                 2.75
# 3      6762812919  42491                   3                 2.00
# 4      6762813105  42491                   3                 2.50
# 6      6762813599  42491                   3                 1.75
# ...           ...    ...                 ...                  ...
# 14612  6762829600  42734                   3                 1.00
# 14613  6762829669  42734                   3                 1.75
# 14615  6762830339  42734                   3                 2.00
# 14616  6762830618  42734                   2                 1.00
# 14617  6762830709  42734                   4                 1.00
#
#        living area  lot area  number of floors  waterfront present  \
# 0             2920      4000               1.5                   0
# ...

# %%
del df['Postal Code']
#del df['Built Year']
#del df['Renovation Year']

# %%
sns.boxplot(x='living area',data=df)
# Out:
# <Axes: xlabel='living area'>

# %%
X = df.iloc[0:,2:20]
X
# Out:
#        number of bedrooms  number of bathrooms  living area  lot area  \
# 0                       4                 2.50         2920      4000
# 1                       5                 2.75         2910      9480
# 3                       3                 2.00         2710      4500
# 4                       3                 2.50         2600      4750
# 6                       3                 1.75         2240     10578
# ...                   ...                  ...          ...       ...
# 14612                   3                 1.00         1400     10425
# 14613                   3                 1.75         1590      7931
# 14615                   3                 2.00         1680      7000
# 14616                   2                 1.00         1070      6120
# 14617                   4                 1.00         1030      6621
#
#        number of floors  waterfront present  number of views  \
# 0                   1.5                   0                0
# ...

# %%
Y = df.iloc[0:,21:]
Y
# Out:
#          Price
# 0      1400000
# 1      1200000
# 3       805000
# 4       790000
# 6       750000
# ...        ...
# 14612   241500
# 14613   240000
# 14615   219200
# 14616   209000
# 14617   205000
#
# [9492 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,Y,test_size=0.11, random_state =161)

# %%
X_train
# Out:
#        number of bedrooms  number of bathrooms  living area  lot area  \
# 13144                   3                 2.50         1230       922
# 8750                    4                 2.50         2660      5539
# 13223                   4                 1.75         1730      9520
# 5530                    4                 2.50         2090      4400
# 13851                   3                 2.00         2070      9000
# ...                   ...                  ...          ...       ...
# 9910                    2                 1.00         1190      3400
# 8487                    3                 1.00         1010      6300
# 7399                    3                 0.75         1270     10092
# 2653                    4                 2.50         2050      5276
# 3284                    4                 2.50         1540      1860
#
#        number of floors  waterfront present  number of views  \
# 13144               2.0                   0                0
# ...

# %%
y_train
# Out:
#         Price
# 13144  399950
# 8750   423000
# 13223  320000
# 5530   455000
# 13851  254000
# ...       ...
# 9910   440000
# 8487   300000
# 7399   316000
# 2653   385000
# 3284   491234
#
# [8447 rows x 1 columns]

# %%
X_test
# Out:
#        number of bedrooms  number of bathrooms  living area  lot area  \
# 12165                   3                 2.00         1820      1357
# 2672                    3                 1.75         1900      8540
# 824                     3                 2.00         1400      6200
# 5225                    4                 2.25         2510      4090
# 3024                    4                 2.25         2160      5600
# ...                   ...                  ...          ...       ...
# 13222                   2                 1.00          950      3090
# 12979                   3                 2.50         2020      7800
# 2651                    4                 2.50         1750      4779
# 5462                    4                 2.25         2115      6234
# 3340                    3                 2.50         2540      4775
#
#        number of floors  waterfront present  number of views  \
# 12165               3.0                   0                0
# ...

# %%
y_test
# Out:
#         Price
# 12165  469950
# 2672   235000
# 824    240000
# 5225   410000
# 3024   756000
# ...       ...
# 13222  330000
# 12979  444950
# 2651   415500
# 5462   272000
# 3340   310000
#
# [1045 rows x 1 columns]

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)

# %%
X_test = scaler.transform(X_test)

# %%
X_test
# Out:
# array([[-0.32145556,  0.04919903,  0.06720678, ..., -0.11200703,
#         -1.87001528,  1.19913275],
#        [-0.32145556, -0.34065484,  0.2071341 , ..., -0.83969878,
#          1.21689452, -1.24102006],
#        [-0.32145556,  0.04919903, -0.66741167, ..., -0.75408798,
#          0.29417692,  1.19913275],
#        ...,
#        [ 0.98587958,  0.82890678, -0.05522963, ..., -0.39024211,
#         -0.71137556, -0.02094366],
#        [ 0.98587958,  0.4390529 ,  0.58318878, ...,  1.45038995,
#         -0.12454115, -1.24102006],
#        [-0.32145556,  0.82890678,  1.32655269, ...,  1.08654408,
#         -0.6019776 , -0.02094366]])

# %%
from sklearn.linear_model import LinearRegression
regression = LinearRegression(n_jobs = -1)

# %%
regression.fit(X_train,y_train)
# Out:
# LinearRegression(n_jobs=-1)

# %%
regression
# Out:
# LinearRegression(n_jobs=-1)

# %%
y_pred = regression.predict(X_test)

# %%
from sklearn.metrics import r2_score
score = r2_score(y_test,y_pred)
print(score)
# Out:
# 0.7025487369413995

# %%
sns.boxplot(data=df)
# Out:
# <Axes: >

# %% [markdown]
# ## **Decision Tree

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
treemodel = DecisionTreeRegressor(max_depth = 10)
treemodel
# Out:
# DecisionTreeRegressor(max_depth=10)

# %%
treemodel.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor(max_depth=10)

# %%
# constructing tree
#import matplotlib.pyplot as plt
#from sklearn import tree
#plt.figure(figsize = (15,10))
#tree.plot_tree(treemodel, filled = True)

# %%
# prediction
y_pred = treemodel.predict(X_test)

# %%
y_pred
# Out:
# array([479950.        , 253039.71111111, 288322.14285714, ...,
#        424716.37142857, 292520.68965517, 293500.        ])

# %%
from sklearn.metrics import accuracy_score, classification_report
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# %%
mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"Mean Squared Error: {mse}")
print(f"Mean Absolute Error: {mae}")
print(f"R2 Score: {r2}")
# Out:
# Mean Squared Error: 6782853514.307615
# Mean Absolute Error: 56414.00224266423
# R2 Score: 0.807961920702636

# %%
#score = accuracy_score(y_pred,y_test)
#print(score)

# %% [markdown]
# # random forest

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
forest = RandomForestRegressor()
forest
# Out:
# RandomForestRegressor()

# %%
forest.fit(X_train,y_train)
# Out:
# D:\anaconda 3\Lib\site-packages\sklearn\base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# RandomForestRegressor()

# %%
# prediction
y_pred = forest.predict(X_test)

# %%
y_pred
# Out:
# array([447061.4 , 242909.24, 320141.35, ..., 391138.  , 304819.87,
#        307001.  ])

# %%
r2 = r2_score(y_test, y_pred)
print(f"R2 Score: {r2}")
# Out:
# R2 Score: 0.8926230794763843

# %%
df.columns
# Out:
# Index(['id', 'Date', 'number of bedrooms', 'number of bathrooms',
#        'living area', 'lot area', 'number of floors', 'waterfront present',
#        'number of views', 'condition of the house', 'grade of the house',
#        'Area of the house(excluding basement)', 'Area of the basement',
#        'Built Year', 'Renovation Year', 'Lattitude', 'Longitude',
#        'living_area_renov', 'lot_area_renov', 'Number of schools nearby',
#        'Distance from the airport', 'Price'],
#       dtype='object')
